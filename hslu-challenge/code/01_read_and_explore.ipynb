# %% [markdown]
# ## Created: 06-May-2026
# ## Daniel Mastropietro
# ## Energy Hackdays Lausanne (7-8 May 2026) www.energydatahackdays.ch

# %%
# Standard libraries
import pickle
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Set display options
pd.set_option("display.max_columns", 100)
plt.style.use("seaborn-v0_8-whitegrid")
plt.rcParams["figure.figsize"] = (14, 5)

# You may add additional imports as needed (e.g., statsmodels, scipy, etc.)
import sys
sys.version
# Out:
# '3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]'

# %%
# Install specialized libraries
#!pip install

# %%
#import nctoolkit
#dir(nctoolkit)

# %%
#help(nctoolkit.open_data)
#df_pv_annual_2019 = nctoolkit.open_data("/content/energy/2019_annual_v1.nc", checks=True)
## Does NOT work... "unable to read data" or similar error. Moving to xarray package (https://docs.xarray.dev/en/stable/user-guide/terminology.html)

import xarray as xr

ds_pv_annual_2019 = xr.open_dataset("/content/energy/2019_annual_v1.nc")
print("Dataset read with xarray, with info:")
print(ds_pv_annual_2019)
print("Available Dataset methods:")
#dir(ds_pv_annual_2019)
# Out:
# Dataset read with xarray, with info:
# <xarray.Dataset> Size: 518MB
# Dimensions:        (unit: 135, time: 8760, azimuth: 6, tilt: 9, size_class: 5)
# Coordinates:
#   * unit           (unit) int64 1kB 4 5 6 7 8 9 10 ... 173 174 175 176 177 178
#   * time           (time) datetime64[ns] 70kB 2019-01-01 ... 2019-12-31T23:00:00
#   * azimuth        (azimuth) int64 48B 0 90 135 180 225 270
#   * tilt           (tilt) int64 72B 0 3 8 15 25 35 45 60 80
#   * size_class     (size_class) <U10 200B '1-10kW' '10-30kW' ... '300-1000kW'
# Data variables:
#     power          (unit, time, azimuth, tilt) float32 255MB ...
#     Wp             (unit, azimuth, tilt, size_class) float32 146kB ...
#     specificPower  (unit, time, azimuth, tilt) float32 255MB ...
#     name           (unit, azimuth, tilt, size_class) <U49 7MB ...
# Available Dataset methods:

# %%
ds_pv_annual_2019.variables
# Out:
# Frozen({'power': <xarray.Variable (unit: 135, time: 8760, azimuth: 6, tilt: 9)> Size: 255MB
# [63860400 values with dtype=float32]
# Attributes:
#     units:              Wh
#     PV_model_PR:        0.8
#     PV_model_mu:        0.2
#     roof_cover_factor:  0.7, 'Wp': <xarray.Variable (unit: 135, azimuth: 6, tilt: 9, size_class: 5)> Size: 146kB
# [36450 values with dtype=float32]
# Attributes:
#     units:        W
#     description:  Installed capacity (Wp) by size class, 'specificPower': <xarray.Variable (unit: 135, time: 8760, azimuth: 6, tilt: 9)> Size: 255MB
# [63860400 values with dtype=float32]
# Attributes:
#     units:    Wh/Wp, 'name': <xarray.Variable (unit: 135, azimuth: 6, tilt: 9, size_class: 5)> Size: 7MB
# [36450 values with dtype=<U49]
# Attributes:
#     description:  Generator name in format CH_RES_PV_BusName_Tilt_Azimuth_Siz..., 'unit': <xarray.IndexVariable 'unit' (unit: 135)> Size: 1kB
# ...

# %%
# Select a subset of the data so that we can upload it to GitHub (as this file weights ~ 150 MB)
ds_pv_annual_2019_subset_size3az90tilt45 = ds_pv_annual_2019.sel(size_class='30-100kW', azimuth=90, tilt=45)
ds_pv_annual_2019_subset_size3az90tilt45
ds_pv_annual_2019_subset_size3az90tilt45.variables
# Out:
# Frozen({'power': <xarray.Variable (unit: 135, time: 8760)> Size: 5MB
# [1182600 values with dtype=float32]
# Attributes:
#     units:              Wh
#     PV_model_PR:        0.8
#     PV_model_mu:        0.2
#     roof_cover_factor:  0.7, 'Wp': <xarray.Variable (unit: 135)> Size: 540B
# [135 values with dtype=float32]
# Attributes:
#     units:        W
#     description:  Installed capacity (Wp) by size class, 'specificPower': <xarray.Variable (unit: 135, time: 8760)> Size: 5MB
# [1182600 values with dtype=float32]
# Attributes:
#     units:    Wh/Wp, 'name': <xarray.Variable (unit: 135)> Size: 26kB
# [135 values with dtype=<U49]
# Attributes:
#     description:  Generator name in format CH_RES_PV_BusName_Tilt_Azimuth_Siz..., 'unit': <xarray.IndexVariable 'unit' (unit: 135)> Size: 1kB
# array([  4,   5,   6,   7,   8,   9,  10,  12,  13,  15,  16,  17,  18,  19,
#         20,  22,  23,  24,  26,  27,  29,  30,  31,  32,  33,  34,  35,  36,
# ...

# %%
ds_pv_annual_2019_subset_size3az90tilt45.to_netcdf("/content/energy/2019_annual_v1_subset_size3az90tilt45.nc")
